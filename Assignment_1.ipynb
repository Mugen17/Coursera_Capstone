# %% [markdown]
# # Capstone Project Assignment 1
# This notebook is to be used for the IBM Data Science Professional course capstone project

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# print("Hello Capstone Project Course!")
